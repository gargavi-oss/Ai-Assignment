# %% [markdown]
# # 💻 Lab Experiment 4: How to Use Git Effectively
#
# ### **Objectives**
# 1. Understand the purpose of version control systems.
# 2. Learn how to set up and configure Git.
# 3. Practice essential Git commands for managing code effectively.
# 4. Explore collaboration workflows with branching and merging.
#
# ---

# %% [markdown]
# # Step 1: Install and Configure Git

# %%
# !git --version

# Configure Git user details (replace with your name & email)
# !git config --global user.name "Your Name"
# !git config --global user.email "your.email@example.com"

# Verify configuration
# !git config --list
# Out:
# git version 2.39.5 (Apple Git-154)
# credential.helper=osxkeychain
# init.defaultbranch=main
# user.name=Your Name
# user.email=your.email@example.com
# filter.lfs.clean=git-lfs clean -- %f
# filter.lfs.smudge=git-lfs smudge -- %f
# filter.lfs.process=git-lfs filter-process
# filter.lfs.required=true
# http.postbuffer=1048576000
# http.maxrequestbuffer=1048576000
# credential.helper=store

# %% [markdown]
# # Step 2: Create a New Repository

# %%
# !git init
# Out:
# mkdir: my_project: File exists
# /Users/avigarg/AI/my_project
# Reinitialized existing Git repository in /Users/avigarg/AI/my_project/.git/
# /Users/avigarg/Library/Python/3.9/lib/python/site-packages/IPython/core/magics/osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %% [markdown]
# # Step 3: Add and Commit Files

# %%
# !echo "Hello Git" > file.txt
# !git status
# Out:
# On branch new_feature
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	Assignment 4.ipynb
# 	Assignment 6.ipynb
#
# nothing added to commit but untracked files present (use "git add" to track)

# %%
# !git add .
# !git commit -m "Initial commit "
# Out:
# On branch new_feature
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	Assignment 4.ipynb
# 	Assignment 6.ipynb
#
# nothing added to commit but untracked files present (use "git add" to track)

# %%
# !git log --oneline
# Out:
# ead05ce (HEAD -> new_feature) Added new feature file
# 868a28f (main) Initial commit with file.txt

# %% [markdown]
# # Step 4: Create and Switch Branches

# %%
# !git branch
# Out:
#   main
# * new_feature

# %%
# !git branch new_feature
# Out:
# fatal: a branch named 'new_feature' already exists

# %%
# !git branch
# Out:
#   main
# * new_feature

# %%
# !git checkout new_feature
# Out:
# Already on 'new_feature'

# %%
# !git branch
# Out:
#   main
# * new_feature

# %%
# !echo "This is a new feature!" > feature.txt

# %%
# !git status
# Out:
# On branch new_feature
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	Assignment 4.ipynb
# 	Assignment 6.ipynb
#
# nothing added to commit but untracked files present (use "git add" to track)

# %%
# !git add feature.txt

# %%
# !git status
# Out:
# On branch new_feature
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	Assignment 4.ipynb
# 	Assignment 6.ipynb
#
# nothing added to commit but untracked files present (use "git add" to track)

# %%
# !git commit -m "Added new feature file"
# Out:
# On branch new_feature
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	Assignment 4.ipynb
# 	Assignment 6.ipynb
#
# nothing added to commit but untracked files present (use "git add" to track)

# %%
# !git branch
# Out:
#   main
# * new_feature

# %%
# !git status
# Out:
# On branch new_feature
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	Assignment 4.ipynb
# 	Assignment 6.ipynb
#
# nothing added to commit but untracked files present (use "git add" to track)

# %% [markdown]
# # Step 5: Merge Branches

# %%
# !git checkout master
# !git merge new_feature
# !ls
# Out:
# error: pathspec 'master' did not match any file(s) known to git
# Already up to date.
# Assignment 4.ipynb Assignment 6.ipynb feature.txt        file.txt

# %% [markdown]
# # Step 6: Connect to Remote Repository

# %% [markdown]
# ### 🧭 Common Git Commands Reference
#
# | Command | Description |
# |----------|-------------|
# | `git init` | Initialize a repository |
# | `git status` | Show file status |
# | `git add <file>` | Stage file changes |
# | `git commit -m "msg"` | Save staged changes with a message |
# | `git branch` | List branches |
# | `git checkout <branch>` | Switch branches |
# | `git merge <branch>` | Merge a branch into the current branch |
# | `git push` | Upload local changes to remote |
#
# ---

# %%
# !git commit -m "Adding assignments"
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# !git branch -M main

# %%
# !git branch
# Out:
# * main

# %%
# !git remote add origin https://github.com/gargavi-oss/Ai-Assignment.git
# Out:
# error: remote origin already exists.

# %%
# !git remote -v
# Out:
# origin	hhttps://github.com/gargavi-oss/Ai-Assignment.git (fetch)
# origin	hhttps://github.com/gargavi-oss/Ai-Assignment.git (push)

# %%
# !git remote remove origin

# %%
# !git remote -v

# %%
# !git remote add origin https://github.com/gargavi-oss/Ai-Assignment.git
# !git push -u origin main
# Out:
# Enumerating objects: 10, done.
# Counting objects: 100% (10/10), done.
# Delta compression using up to 8 threads
# Compressing objects: 100% (7/7), done.
# Writing objects: 100% (10/10), 277.79 KiB | 21.37 MiB/s, done.
# Total 10 (delta 1), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (1/1), done.
# To https://github.com/gargavi-oss/Ai-Assignment.git
#  * [new branch]      main -> main
# branch 'main' set up to track 'origin/main'.
